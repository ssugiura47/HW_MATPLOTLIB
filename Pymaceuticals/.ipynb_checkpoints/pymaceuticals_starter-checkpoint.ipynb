# %% [markdown]
# ## Observations and Insights

# %%
# Look across all previously generated figures and tables and write at least three observations or inferences that can be made from the data. Include these observations at the top of notebook.

#1 The best data we got was from Ramicane Regimen. This data had the smallest variance in the data and the smallest standard deviation. Even though they were the second to first regimen with the most number of mice, the data points for this regimen were not far from each other.
#2 Out of 248 mice after removing the one mouse in the beginning, we only had one outlier mouse based on the quantitative 1.5 IQR rule.
#3 Based on an example we saw for Mouse ID s185 from Capomulim Regimen, as timepoint increased the volume of the tumor decreased.
#4 We saw a linear positive regression in our scatterplot for all mouse in Capomulim Regimen that as the weight of mouse increased, average tumor volume increased.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
# Display the data table for preview
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
len(merge_df["Mouse ID"].value_counts())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupemouseID = merge_df.loc[merge_df.duplicated(subset=['Mouse ID','Timepoint']),'Mouse ID'].unique()
dupemouseID = dupemouseID[0]
dupemouseID
# Out:
# 'g989'

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dupemouse = merge_df.loc[merge_df["Mouse ID"] == dupemouseID,:]
dupemouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
dupemouse = merge_df[merge_df['Mouse ID'] == dupemouseID].index
merge_df.drop(dupemouse, inplace=True)
merge_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
len(merge_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# This method is the most straighforward, creating multiple series and putting them all together at the end.

mean = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
median = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
variance = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
std_dev = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()

regimensummary = np.array(mean.index.tolist())
regimen_mean = np.array(mean.values.tolist())
regimen_median = np.array(median.values.tolist())
regimen_var = np.array(variance.values.tolist())
regimen_std_dev = np.array(std_dev.values.tolist())

Summary_df = pd.DataFrame({
    "Regimen" : regimensummary,
    "Mean": regimen_mean,
    "Median": regimen_median,
    "Variance": regimen_var,
    "Standard Deviation": regimen_std_dev,

})
Summary_df
# Out:
#      Regimen       Mean     Median   Variance  Standard Deviation
# 0  Capomulin  40.675741  41.557809  24.947764            4.994774
# 1   Ceftamin  52.591172  51.776157  39.290177            6.268188
# 2  Infubinol  52.884795  51.820584  43.128684            6.567243
# 3   Ketapril  55.235638  53.698743  68.553577            8.279709
# 4   Naftisol  54.331565  52.509285  66.173479            8.134708
# 5    Placebo  54.033581  52.288934  61.168083            7.821003
# 6   Propriva  52.320930  50.446266  43.852013            6.622085
# 7   Ramicane  40.216745  40.673236  23.486704            4.846308
# 8   Stelasyn  54.233149  52.431737  59.450562            7.710419
# 9  Zoniferol  53.236507  51.818479  48.533355            6.966589

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# This method is the most straighforward, creating multiple series and putting them all together at the end.
regimen_df = merge_df.groupby("Drug Regimen").describe()
regimen_df
# Out:
#              Age_months                                                     \
#                   count       mean       std  min    25%   50%   75%   max
# Drug Regimen
# Capomulin         230.0  13.456522  7.721423  1.0   7.00  16.5  20.0  24.0
# Ceftamin          178.0  13.247191  8.071406  2.0   6.00  12.0  20.0  24.0
# Infubinol         178.0  16.230337  7.510278  1.0   8.00  20.0  23.0  24.0
# Ketapril          188.0  15.659574  6.019670  1.0  11.75  18.0  19.0  24.0
# Naftisol          186.0  12.000000  6.715855  2.0   8.00   9.0  19.0  23.0
# Placebo           181.0  10.734807  6.354907  1.0   5.00  10.0  17.0  21.0
# Propriva          148.0  10.006757  6.946341  1.0   5.00   7.5  16.0  24.0
# Ramicane          228.0  10.684211  5.946629  1.0   7.00   9.0  18.0  23.0
# Stelasyn          181.0  12.784530  7.939562  1.0   4.00  14.0  21.0  23.0
# Zoniferol         182.0  12.598901  5.786114  2.0   8.00  12.5  16.0  24.0
#
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

regimencounts = merge_df["Drug Regimen"].value_counts()
regimen = np.array(regimencounts.index.tolist())
countsperregimen = np.array(regimencounts.values.tolist())
plt.bar(regimen, countsperregimen, color='b', alpha=0.5, align="center")
plt.xticks(rotation="vertical")

plt.title("Number of Mice by Regimen")
plt.xlabel("Regimen Drug")
plt.ylabel("Number of Mice")
plt.ylim(0,275)
# Out:
# (0, 275)

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas.

pandaplot = merge_df.groupby("Drug Regimen")['Mouse ID'].count().plot(kind='bar')
pandaplot.set(xlabel = "Regimen Drug", ylabel = "Number of Mice", title = "Number of Mice by Regimen")
# Out:
# [Text(0, 0.5, 'Number of Mice'),
#  Text(0.5, 0, 'Regimen Drug'),
#  Text(0.5, 1.0, 'Number of Mice by Regimen')]

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gender_group = merge_df.groupby("Sex").count()
gender_count = gender_group["Mouse ID"]
labels = np.array(gender_count.index.tolist())
sizes = np.array(gender_count.values.tolist())
colors = ["red","lightskyblue"]
explode = (0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1745512aa08>,
# ...
#  [Text(-0.7320888280116858, -0.8210030133321538, 'Female'),
#   Text(0.7320888280116862, 0.8210030133321533, 'Male')],
#  [Text(-0.399321178915465, -0.447819825453902, '49.0%'),
#   Text(0.39932117891546515, 0.4478198254539018, '51.0%')])

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gendermerge_df = merge_df
gendermerge_df = pd.DataFrame({'Gender': np.array(gender_count.values.tolist())},
                  index=np.array(gender_count.index.tolist()))
plot = gendermerge_df.plot.pie(y='Gender', figsize=(5, 5))

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

RegimenTimepoint_df = merge_df.groupby("Mouse ID")["Timepoint"].max().reset_index()
mergeRegimenTimepoint_df = pd.merge(merge_df, RegimenTimepoint_df)
mergeRegimenTimepoint_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)

fourRegimen = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

FinalTumorVol = []

for regimen in fourRegimen:
    final_tumor_vol = mergeRegimenTimepoint_df.loc[mergeRegimenTimepoint_df["Drug Regimen"] == regimen, 'Tumor Volume (mm3)']
    FinalTumorVol.append(final_tumor_vol)
    # Calculate the IQR and quantitatively determine if there are any potential outliers. 
    quartiles = final_tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(f"This data is an outlier: {outliers} in Regimen {regimen}" )
# Out:
# This data is an outlier: Series([], Name: Tumor Volume (mm3), dtype: float64) in Regimen Capomulin
# This data is an outlier: Series([], Name: Tumor Volume (mm3), dtype: float64) in Regimen Ramicane
# This data is an outlier: 74    36.321346
# Name: Tumor Volume (mm3), dtype: float64 in Regimen Infubinol
# This data is an outlier: Series([], Name: Tumor Volume (mm3), dtype: float64) in Regimen Ceftamin

# %%
boxplotFour = plt.boxplot(FinalTumorVol, labels = fourRegimen)
plt.title("Four Regimen Boxplot for Outliers")
plt.xlabel("Regimen")
plt.ylabel("Tumor Volume in mm3")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
CapTable = merge_df.loc[merge_df["Drug Regimen"] == "Capomulin"]
CapMouse = CapTable.loc[CapTable["Mouse ID"] == "s185"]
plt.title("Tumor Volume Over Timepoint for Mouse ID s185 for Capomulin")
plt.xlabel("Timepoint ")
plt.ylabel("Tumor Volume in mm3")
plt.plot(CapMouse['Timepoint'], CapMouse["Tumor Volume (mm3)"])

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
CapTableGroup = CapTable.groupby("Mouse ID").mean()
plt.title("Mouse Weight Vesus Tumor Volume for Mice for Capomulin")
plt.xlabel("Mouse Weight in g ")
plt.ylabel("Tumor Volume in mm3")
plt.scatter(CapTableGroup['Weight (g)'],CapTableGroup["Tumor Volume (mm3)"] )

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(CapTableGroup['Weight (g)'],CapTableGroup["Tumor Volume (mm3)"])
correlation[0]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(CapTableGroup['Weight (g)'],CapTableGroup["Tumor Volume (mm3)"])
regress_values = CapTableGroup['Weight (g)'] * slope + intercept
plt.scatter(CapTableGroup['Weight (g)'],CapTableGroup["Tumor Volume (mm3)"] )
plt.plot(CapTableGroup['Weight (g)'],regress_values,"r-")
plt.title("Mouse Weight Vesus Tumor Volume for Mice for Capomulin")
plt.xlabel("Mouse Weight in g ")
plt.ylabel("Tumor Volume in mm3")
# Out:
# Text(0, 0.5, 'Tumor Volume in mm3')
